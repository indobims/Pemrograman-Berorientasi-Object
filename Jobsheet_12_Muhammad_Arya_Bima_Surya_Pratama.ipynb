# %% [markdown]
# <a href="https://colab.research.google.com/github/indobims/Pemrograman-Berorientasi-Object/blob/main/Jobsheet_12_Muhammad_Arya_Bima_Surya_Pratama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Nama : Muhammad Arya Bima Surya Pratama** <br>
# **Nim : 4.33.25.1.15** <br>
# **Kelas : Ti-1B**

# %% [markdown]
# #Praktikum 1: Persiapan Data (CSV)

# %%
# %%writefile lokasi_semarang.csv
# Nama,Latitude,Longitude,Tipe,Deskripsi
# Lawang Sewu,-6.9840,110.4105,Wisata Sejarah,Bangunan bersejarah peninggalan Belanda dengan banyak pintu.
# Simpang Lima,-6.9929,110.4200,Landmark,"Alun-alun pusat kota Semarang, tempat berkumpul populer."
# Masjid Agung Jawa Tengah,-6.9892,110.4452,Tempat Ibadah,Masjid besar dengan arsitektur megah dan menara pandang Asmaul Husna.
# Klenteng Sam Poo Kong,-6.9980,110.4030,Tempat Ibadah,Klenteng bersejarah peninggalan Laksamana Cheng Ho.
# Brown Canyon,-7.0375,110.4875,Wisata Alam,"Tebing bekas penambangan galian C yang unik menyerupai Grand Canyon."
# Lumpia Gang Lombok,-6.9718,110.4255,Kuliner,Salah satu tempat makan lumpia legendaris dan otentik di Semarang.
# Kota Lama,-6.9690,110.4250,Wisata Sejarah,"Kawasan cagar budaya dengan bangunan-bangunan kuno bergaya Eropa."
# Pantai Marina,-6.9585,110.3875,Wisata Alam,Kawasan pantai rekreasi di bagian utara kota.
# Kampoeng Kopi Banaran,-7.2780,110.4010,Wisata Alam,"Agrowisata kebun kopi dengan pemandangan dan restoran."
# Toko Oen,-6.9715,110.4235,Kuliner,Restoran dan toko es krim legendaris sejak zaman kolonial.
# Out:
# Writing lokasi_semarang.csv

# %% [markdown]
# #Praktikum 2: Membaca CSV dengan Pandas

# %%
import pandas as pd

NAMA_FILE_CSV = "lokasi_semarang.csv"

def baca_data_lokasi(nama_file: str) -> pd.DataFrame | None:
    """Membaca data lokasi dari file CSV menggunakan Pandas."""
    print(f"Mencoba membaca file CSV: {nama_file}")
    try:
        dataframe = pd.read_csv(nama_file)
        print(" -> File CSV berhasil dibaca.")
        return dataframe
    except FileNotFoundError:
        print(f" -> ERROR: File '{nama_file}' tidak ditemukan!")
        return None
    except pd.errors.EmptyDataError:
        print(f" -> ERROR: File '{nama_file}' kosong.")
        return None
    except Exception as e:
        print(f" -> ERROR saat membaca file CSV: {type(e).__name__} - {e}")
        return None

print("--- Memulai Praktikum 2: Membaca CSV ---")
df_lokasi = baca_data_lokasi(NAMA_FILE_CSV)

if df_lokasi is not None:
    print("\n--- Inspeksi Awal DataFrame ---")
    print("\n1. Lima Baris Pertama (head()):")
    print(df_lokasi.head())

    print("\n2. Informasi DataFrame (info()):")
    df_lokasi.info()

    jumlah_baris, jumlah_kolom = df_lokasi.shape
    print(f"\n3. Dimensi Data:\n Jumlah Lokasi (Baris): {jumlah_baris}\n Jumlah Atribut (Kolom): {jumlah_kolom}")

    print(f"\n4. Nama Kolom:\n {list(df_lokasi.columns)}")
else:
    print("\nTidak dapat melanjutkan inspeksi karena gagal membaca file CSV.")
print("\n--- Praktikum 2 Selesai ---")
# Out:
# --- Memulai Praktikum 2: Membaca CSV ---
# Mencoba membaca file CSV: lokasi_semarang.csv
#  -> File CSV berhasil dibaca.
#
# --- Inspeksi Awal DataFrame ---
#
# 1. Lima Baris Pertama (head()):
#                        Nama  Latitude  Longitude            Tipe  \
# 0               Lawang Sewu   -6.9840   110.4105  Wisata Sejarah
# 1              Simpang Lima   -6.9929   110.4200        Landmark
# 2  Masjid Agung Jawa Tengah   -6.9892   110.4452   Tempat Ibadah
# 3     Klenteng Sam Poo Kong   -6.9980   110.4030   Tempat Ibadah
# 4              Brown Canyon   -7.0375   110.4875     Wisata Alam
#
#                                            Deskripsi
# 0  Bangunan bersejarah peninggalan Belanda dengan...
# 1  Alun-alun pusat kota Semarang, tempat berkumpu...
# 2  Masjid besar dengan arsitektur megah dan menar...
# 3  Klenteng bersejarah peninggalan Laksamana Chen...
# 4  Tebing bekas penambangan galian C yang unik me...
#
# 2. Informasi DataFrame (info()):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Nama       10 non-null     object
#  1   Latitude   10 non-null     float64
#  2   Longitude  10 non-null     float64
#  3   Tipe       10 non-null     object
#  4   Deskripsi  10 non-null     object
# dtypes: float64(2), object(3)
# memory usage: 532.0+ bytes
#
# 3. Dimensi Data:
#  Jumlah Lokasi (Baris): 10
#  Jumlah Atribut (Kolom): 5
#
# 4. Nama Kolom:
#  ['Nama', 'Latitude', 'Longitude', 'Tipe', 'Deskripsi']
#
# --- Praktikum 2 Selesai ---

# %% [markdown]
# #Praktikum 3: Mendesain Kelas OOP

# %%
from abc import ABC, abstractmethod

# --- PRAKTIKUM 3: Mendesain Kelas OOP ---
class Lokasi(ABC):
    def __init__(self, nama: str, latitude: float, longitude: float):
        self.nama = str(nama) if nama else "Tanpa Nama"
        try:
            self.latitude = float(latitude)
            self.longitude = float(longitude)
        except (ValueError, TypeError, SystemError):
            self.latitude, self.longitude = 0.0, 0.0

    def get_koordinat(self) -> tuple:
        return (self.latitude, self.longitude)

    @abstractmethod
    def get_info_popup(self) -> str:
        pass

    def __repr__(self) -> str:
        return f"{type(self).__name__}(nama='{self.nama}', lat={self.latitude:.4f}, lon={self.longitude:.4f})"

    def __str__(self) -> str:
        return f"{self.nama} [{type(self).__name__}]"

class TempatWisata(Lokasi):
    def __init__(self, nama: str, latitude: float, longitude: float, jenis: str, deskripsi: str):
        super().__init__(nama, latitude, longitude)
        self.jenis_wisata = str(jenis) if jenis else "Umum"
        self.deskripsi = str(deskripsi) if deskripsi else "Tidak ada deskripsi."

    def get_info_popup(self) -> str:
        return f"<h4><b>{self.nama}</b></h4><i>{self.jenis_wisata}</i><br><br>{self.deskripsi}<br><br>Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})"

class Kuliner(Lokasi):
    def __init__(self, nama: str, latitude: float, longitude: float, menu_andalan: str):
        super().__init__(nama, latitude, longitude)
        self.menu_andalan = str(menu_andalan) if menu_andalan else "Tidak diketahui"

    def get_info_popup(self) -> str:
        return f"<h4><b>{self.nama}</b></h4><i>Kuliner</i><br><br>Menu Andalan: {self.menu_andalan}<br><br>Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})"

class TempatIbadah(Lokasi):
    def __init__(self, nama: str, latitude: float, longitude: float, agama: str = "Umum", deskripsi: str = ""):
        super().__init__(nama, latitude, longitude)
        self.agama = str(agama) if agama else "Umum"
        self.deskripsi = str(deskripsi) if deskripsi else "Tempat Ibadah"

    def get_info_popup(self) -> str:
        return f"<h4><b>{self.nama}</b></h4><i>Tempat Ibadah ({self.agama})</i><br><br>{self.deskripsi}<br><br>Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})"

print("--- Praktikum 3 Selesai: Kelas OOP berhasil didefinisikan ---")
# Out:
# --- Praktikum 3 Selesai: Kelas OOP berhasil didefinisikan ---

# %% [markdown]
# #Praktikum 4: Membuat Objek dari Data

# %%
import pandas as pd

# --- PRAKTIKUM 4: Membuat Objek dari Data Pandas ---
def buat_objek_lokasi_dari_df(dataframe: pd.DataFrame) -> list:
    list_objek_lokasi = []

    if dataframe is None or dataframe.empty:
        print("DataFrame kosong atau None, tidak ada objek dibuat.")
        return list_objek_lokasi

    print("\nMembuat objek dari DataFrame...")
    for index, row in dataframe.iterrows():
        nama = row.get('Nama', None)
        lat = row.get('Latitude', None)
        lon = row.get('Longitude', None)
        tipe = row.get('Tipe', 'Lainnya')
        deskripsi = row.get('Deskripsi', '')

        if pd.isna(nama) or pd.isna(lat) or pd.isna(lon):
            continue

        objek = None
        try:
            if 'Wisata' in tipe or tipe == 'Landmark':
                objek = TempatWisata(nama, lat, lon, tipe, deskripsi)
            elif tipe == 'Kuliner':
                objek = Kuliner(nama, lat, lon, deskripsi)
            elif 'Ibadah' in tipe:
                agama_info = "Umum"
                if "Islam" in tipe: agama_info = "Islam"
                elif "Kristen" in tipe: agama_info = "Kristen"
                elif "Klenteng" in tipe: agama_info = "Tridharma"
                objek = TempatIbadah(nama, lat, lon, agama_info, deskripsi)

            if objek:
                list_objek_lokasi.append(objek)

        except Exception as e:
            print(f" -> GAGAL membuat objek untuk '{nama}' di baris {index}: {e}")

    print(f"Total {len(list_objek_lokasi)} objek lokasi berhasil dibuat dari {len(dataframe)} baris data.")
    return list_objek_lokasi

# Eksekusi Utama Praktikum 4
print("--- Memulai Praktikum 4: Membuat Objek dari Data Pandas ---")

# Memastikan df_lokasi dari Praktikum 2 sudah ada
try:
    list_semua_lokasi = buat_objek_lokasi_dari_df(df_lokasi)
    print("\n--- Daftar Objek Lokasi yang Berhasil Dibuat ---")
    if list_semua_lokasi:
        for idx, lok in enumerate(list_semua_lokasi):
            print(f" {idx+1}. {repr(lok)}")
    else:
        print("Tidak ada objek lokasi yang dibuat.")
except NameError:
    print("ERROR: Variabel 'df_lokasi' belum didefinisikan. Pastikan Cell Praktikum 2 sudah dijalankan!")

print("\n--- Praktikum 4 Selesai ---")
# Out:
# --- Memulai Praktikum 4: Membuat Objek dari Data Pandas ---
#
# Membuat objek dari DataFrame...
# Total 10 objek lokasi berhasil dibuat dari 10 baris data.
#
# --- Daftar Objek Lokasi yang Berhasil Dibuat ---
#  1. TempatWisata(nama='Lawang Sewu', lat=-6.9840, lon=110.4105)
#  2. TempatWisata(nama='Simpang Lima', lat=-6.9929, lon=110.4200)
#  3. TempatIbadah(nama='Masjid Agung Jawa Tengah', lat=-6.9892, lon=110.4452)
#  4. TempatIbadah(nama='Klenteng Sam Poo Kong', lat=-6.9980, lon=110.4030)
#  5. TempatWisata(nama='Brown Canyon', lat=-7.0375, lon=110.4875)
#  6. Kuliner(nama='Lumpia Gang Lombok', lat=-6.9718, lon=110.4255)
#  7. TempatWisata(nama='Kota Lama', lat=-6.9690, lon=110.4250)
#  8. TempatWisata(nama='Pantai Marina', lat=-6.9585, lon=110.3875)
#  9. TempatWisata(nama='Kampoeng Kopi Banaran', lat=-7.2780, lon=110.4010)
#  10. Kuliner(nama='Toko Oen', lat=-6.9715, lon=110.4235)
#
# --- Praktikum 4 Selesai ---

# %% [markdown]
# #Praktikum 5: Visualisasi dengan Folium

# %%
import folium

NAMA_FILE_PETA = "peta_interaktif_semarang.html"

# --- PRAKTIKUM 5: Visualisasi Peta Dasar ---
def buat_peta_lokasi_folium_dasar(list_objek: list, file_output: str = NAMA_FILE_PETA):
    if not list_objek:
        print("Tidak ada objek lokasi untuk dipetakan.")
        return None

    print(f"\nMemulai pembuatan peta Folium dari {len(list_objek)} lokasi...")

    try:
        lat_tengah = list_objek[0].latitude
        lon_tengah = list_objek[0].longitude
    except IndexError:
        lat_tengah, lon_tengah = -6.9929, 110.4200

    peta = folium.Map(location=[lat_tengah, lon_tengah], zoom_start=13, tiles="OpenStreetMap")
    print(f" -> Objek peta dibuat, berpusat di ({lat_tengah:.4f}, {lon_tengah:.4f})")

    jumlah_marker_valid = 0

    for lok in list_objek:
        koordinat = lok.get_koordinat()
        if koordinat != (0.0, 0.0):
            info_popup_html = lok.get_info_popup()
            folium.Marker(
                location=koordinat,
                popup=folium.Popup(info_popup_html, max_width=300),
                tooltip=lok.nama
            ).add_to(peta)
            jumlah_marker_valid += 1
        else:
            print(f" -> Melewati marker untuk '{lok.nama}' karena koordinat tidak valid.")

    try:
        peta.save(file_output)
        print(f"\n-> Peta berhasil dibuat dan disimpan sebagai '{file_output}'.")
        print(f"   Total marker ditambahkan: {jumlah_marker_valid}")
    except Exception as e:
        print(f"\nERROR saat menyimpan peta Folium: {type(e).__name__} - {e}")

    return peta

# Eksekusi Praktikum 5
print("--- Memulai Praktikum 5: Visualisasi Peta dengan Folium ---")
peta_dasar = buat_peta_lokasi_folium_dasar(list_semua_lokasi, NAMA_FILE_PETA)
print(f"\nSilakan buka file {NAMA_FILE_PETA} atau lihat hasil render di bawah ini.")
print("\n--- Praktikum 5 Selesai ---")

# Tampilkan di Colab
peta_dasar
# Out:
# --- Memulai Praktikum 5: Visualisasi Peta dengan Folium ---
#
# Memulai pembuatan peta Folium dari 10 lokasi...
#  -> Objek peta dibuat, berpusat di (-6.9840, 110.4105)
#
# -> Peta berhasil dibuat dan disimpan sebagai 'peta_interaktif_semarang.html'.
#    Total marker ditambahkan: 10
#
# Silakan buka file peta_interaktif_semarang.html atau lihat hasil render di bawah ini.
#
# --- Praktikum 5 Selesai ---
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b98b25214a82eb815df77542ddb48e11 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b98b25214a82eb815df77542ddb48e11&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b98b25214a82eb815df77542ddb48e11 = L.map(
#                 &quot;map_b98b25214a82eb815df77542ddb48e11&quot;,
#                 {
#                     center: [-6.984, 110.4105],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f4158b554a061a8c509f5c6b58c162b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8f4158b554a061a8c509f5c6b58c162b.addTo(map_b98b25214a82eb815df77542ddb48e11);
#
#
#             var marker_91a0d3ade2ee217270fa5cf2dad09aaf = L.marker(
#                 [-6.984, 110.4105],
#                 {
# }
#             ).addTo(map_b98b25214a82eb815df77542ddb48e11);
#
#
#         var popup_e8ed0fdf443cb398eaf6bcd12f6a2fe4 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_085c7c53af0f4437f476d6ac67191090 = $(`&lt;div id=&quot;html_085c7c53af0f4437f476d6ac67191090&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;&lt;b&gt;Lawang Sewu&lt;/b&gt;&lt;/h4&gt;&lt;i&gt;Wisata Sejarah&lt;/i&gt;&lt;br&gt;&lt;br&gt;Bangunan bersejarah peninggalan Belanda dengan banyak pintu.&lt;br&gt;&lt;br&gt;Koordinat: (-6.9840, 110.4105)&lt;/div&gt;`)[0];
#                 popup_e8ed0fdf443cb398eaf6bcd12f6a2fe4.setContent(html_085c7c53af0f4437f476d6ac67191090);
#
#
#
#         marker_91a0d3ade2ee217270fa5cf2dad09aaf.bindPopup(popup_e8ed0fdf443cb398eaf6bcd12f6a2fe4)
#         ;
#
#
#
#
#             marker_91a0d3ade2ee217270fa5cf2dad09aaf.bindTooltip(
#                 `&lt;div&gt;
#                      Lawang Sewu
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_46f686a9ead84a248d5e21a7a66c6d67 = L.marker(
#                 [-6.9929, 110.42],
#                 {
# }
#             ).addTo(map_b98b25214a82eb815df77542ddb48e11);
#
#
#         var popup_7607aa23e383900f1f1ce81219b55356 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_633142e72d3085ec063b34da0cf3f622 = $(`&lt;div id=&quot;html_633142e72d3085ec063b34da0cf3f622&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;&lt;b&gt;Simpang Lima&lt;/b&gt;&lt;/h4&gt;&lt;i&gt;Landmark&lt;/i&gt;&lt;br&gt;&lt;br&gt;Alun-alun pusat kota Semarang, tempat berkumpul populer.&lt;br&gt;&lt;br&gt;Koordinat: (-6.9929, 110.4200)&lt;/div&gt;`)[0];
#                 popup_7607aa23e383900f1f1ce81219b55356.setContent(html_633142e72d3085ec063b34da0cf3f622);
#
#
#
#         marker_46f686a9ead84a248d5e21a7a66c6d67.bindPopup(popup_7607aa23e383900f1f1ce81219b55356)
#         ;
#
#
#
#
#             marker_46f686a9ead84a248d5e21a7a66c6d67.bindTooltip(
#                 `&lt;div&gt;
#                      Simpang Lima
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_c242c0ebc10f014de053b1ca6d34dcc9 = L.marker(
#                 [-6.9892, 110.4452],
#                 {
# }
#             ).addTo(map_b98b25214a82eb815df77542ddb48e11);
#
#
#         var popup_45de89e56f5a8c33eaba758d9c3471a5 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_5654066528f8b8f30c0bf8085341f065 = $(`&lt;div id=&quot;html_5654066528f8b8f30c0bf8085341f065&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;&lt;b&gt;Masjid Agung Jawa Tengah&lt;/b&gt;&lt;/h4&gt;&lt;i&gt;Tempat Ibadah (Umum)&lt;/i&gt;&lt;br&gt;&lt;br&gt;Masjid besar dengan arsitektur megah dan menara pandang Asmaul Husna.&lt;br&gt;&lt;br&gt;Koordinat: (-6.9892, 110.4452)&lt;/div&gt;`)[0];
#                 popup_45de89e56f5a8c33eaba758d9c3471a5.setContent(html_5654066528f8b8f30c0bf8085341f065);
#
#
#
#         marker_c242c0ebc10f014de053b1ca6d34dcc9.bindPopup(popup_45de89e56f5a8c33eaba758d9c3471a5)
#         ;
#
#
#
#
#             marker_c242c0ebc10f014de053b1ca6d34dcc9.bindTooltip(
#                 `&lt;div&gt;
#                      Masjid Agung Jawa Tengah
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_b456476b97c6648dad71bd5093ccadb4 = L.marker(
#                 [-6.998, 110.403],
#                 {
# }
#             ).addTo(map_b98b25214a82eb815df77542ddb48e11);

# %% [markdown]
# #Praktikum 6: File Handling Tambahan (Log)

# %%
import folium
import datetime
import os

FILE_LOG = "proses_peta.log"

# --- PRAKTIKUM 6: Fungsi Logging ---
def tulis_log(pesan: str, file_log: str = FILE_LOG):
    """Menulis pesan log ke file dengan timestamp, menggunakan mode append."""
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    try:
        with open(file_log, 'a', encoding='utf-8') as f:
            f.write(f"[{timestamp}] {pesan}\n")
    except IOError as e:
        print(f"ERROR: Gagal menulis ke file log '{file_log}': {e}")

# --- PRAKTIKUM 6: Pembuatan Peta yang Diperbarui (dengan Logging) ---
def buat_peta_lokasi_folium_log(list_objek: list, file_output: str):
    nama_fungsi = "buat_peta_lokasi_folium"

    if not list_objek:
        pesan_log = f"[{nama_fungsi}] Gagal: Tidak ada data lokasi untuk dipetakan."
        print(pesan_log)
        tulis_log(pesan_log)
        return None

    print(f"\n[{nama_fungsi}] Memulai pembuatan peta dari {len(list_objek)} lokasi...")
    tulis_log(f"[{nama_fungsi}] Memulai pembuatan peta '{file_output}' dengan {len(list_objek)} lokasi.")

    try:
        lat_tengah = list_objek[0].latitude
        lon_tengah = list_objek[0].longitude
    except IndexError:
        lat_tengah, lon_tengah = -6.9929, 110.4200

    peta = folium.Map(location=[lat_tengah, lon_tengah], zoom_start=12)

    jumlah_marker = 0
    lokasi_dilewati = []

    for lok in list_objek:
        koordinat = lok.get_koordinat()
        if koordinat != (0.0, 0.0):
            info_popup_html = lok.get_info_popup()
            folium.Marker(
                location=koordinat,
                popup=folium.Popup(info_popup_html, max_width=300),
                tooltip=lok.nama
            ).add_to(peta)
            jumlah_marker += 1
        else:
            lokasi_dilewati.append(lok.nama)

    if lokasi_dilewati:
        pesan_lewat = f"[{nama_fungsi}] Melewati marker untuk: {', '.join(lokasi_dilewati)} (koordinat tidak valid)."
        print(f" -> Peringatan: {pesan_lewat}")
        tulis_log(pesan_lewat)

    try:
        peta.save(file_output)
        pesan_sukses = f"[{nama_fungsi}] Peta '{file_output}' berhasil dibuat dengan {jumlah_marker} marker."
        print(f"-> {pesan_sukses}")
        tulis_log(pesan_sukses)
    except Exception as e:
        pesan_error = f"[{nama_fungsi}] ERROR saat menyimpan peta '{file_output}': {type(e).__name__} - {e}"
        print(f"-> {pesan_error}")
        tulis_log(pesan_error)

    return peta

# Eksekusi Praktikum 6
print("--- Memulai Praktikum 6: File Handling Tambahan (Log) ---")

# (Opsional) Hapus log lama jika ingin mulai bersih saat di-run ulang
if os.path.exists(FILE_LOG):
    os.remove(FILE_LOG)
    print(f"File log lama '{FILE_LOG}' dihapus.")

# Kita buat peta kedua untuk demo logging
print("\nMenjalankan pembuatan peta lagi untuk demo log append...")
peta_dengan_log = buat_peta_lokasi_folium_log(list_semua_lokasi, "peta_kedua.html")

print(f"\nSilakan periksa isi file log '{FILE_LOG}' untuk melihat catatan proses.")

print("\n--- Isi dari proses_peta.log ---")
with open(FILE_LOG, 'r') as f:
    print(f.read())

print("--- Praktikum 6 Selesai ---")

# Tampilkan di Colab
peta_dengan_log
# Out:
# --- Memulai Praktikum 6: File Handling Tambahan (Log) ---
#
# Menjalankan pembuatan peta lagi untuk demo log append...
#
# [buat_peta_lokasi_folium] Memulai pembuatan peta dari 10 lokasi...
# -> [buat_peta_lokasi_folium] Peta 'peta_kedua.html' berhasil dibuat dengan 10 marker.
#
# Silakan periksa isi file log 'proses_peta.log' untuk melihat catatan proses.
#
# --- Isi dari proses_peta.log ---
# [2026-06-21 13:00:46] [buat_peta_lokasi_folium] Memulai pembuatan peta 'peta_kedua.html' dengan 10 lokasi.
# [2026-06-21 13:00:46] [buat_peta_lokasi_folium] Peta 'peta_kedua.html' berhasil dibuat dengan 10 marker.
#
# --- Praktikum 6 Selesai ---
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_657428fcbb78bf5e0f3af1cea024efef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_657428fcbb78bf5e0f3af1cea024efef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_657428fcbb78bf5e0f3af1cea024efef = L.map(
#                 &quot;map_657428fcbb78bf5e0f3af1cea024efef&quot;,
#                 {
#                     center: [-6.984, 110.4105],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_22196084f05a7a2572a05dadf26d28bb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_22196084f05a7a2572a05dadf26d28bb.addTo(map_657428fcbb78bf5e0f3af1cea024efef);
#
#
#             var marker_dc5a4a002a488f88c8a0f5f59de5053a = L.marker(
#                 [-6.984, 110.4105],
#                 {
# }
#             ).addTo(map_657428fcbb78bf5e0f3af1cea024efef);
#
#
#         var popup_c190daceb485f826929a7aef7169658f = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_57ba2dca6f7a112476e78d450bf7efb2 = $(`&lt;div id=&quot;html_57ba2dca6f7a112476e78d450bf7efb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;&lt;b&gt;Lawang Sewu&lt;/b&gt;&lt;/h4&gt;&lt;i&gt;Wisata Sejarah&lt;/i&gt;&lt;br&gt;&lt;br&gt;Bangunan bersejarah peninggalan Belanda dengan banyak pintu.&lt;br&gt;&lt;br&gt;Koordinat: (-6.9840, 110.4105)&lt;/div&gt;`)[0];
#                 popup_c190daceb485f826929a7aef7169658f.setContent(html_57ba2dca6f7a112476e78d450bf7efb2);
#
#
#
#         marker_dc5a4a002a488f88c8a0f5f59de5053a.bindPopup(popup_c190daceb485f826929a7aef7169658f)
#         ;
#
#
#
#
#             marker_dc5a4a002a488f88c8a0f5f59de5053a.bindTooltip(
#                 `&lt;div&gt;
#                      Lawang Sewu
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_a6ac822f90dba2c048cf906bedb8e3ed = L.marker(
#                 [-6.9929, 110.42],
#                 {
# }
#             ).addTo(map_657428fcbb78bf5e0f3af1cea024efef);
#
#
#         var popup_cc40b2e8539a04a9ad72934710d52593 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_1b3ce494c2afdb6a7ddf7364077515eb = $(`&lt;div id=&quot;html_1b3ce494c2afdb6a7ddf7364077515eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;&lt;b&gt;Simpang Lima&lt;/b&gt;&lt;/h4&gt;&lt;i&gt;Landmark&lt;/i&gt;&lt;br&gt;&lt;br&gt;Alun-alun pusat kota Semarang, tempat berkumpul populer.&lt;br&gt;&lt;br&gt;Koordinat: (-6.9929, 110.4200)&lt;/div&gt;`)[0];
#                 popup_cc40b2e8539a04a9ad72934710d52593.setContent(html_1b3ce494c2afdb6a7ddf7364077515eb);
#
#
#
#         marker_a6ac822f90dba2c048cf906bedb8e3ed.bindPopup(popup_cc40b2e8539a04a9ad72934710d52593)
#         ;
#
#
#
#
#             marker_a6ac822f90dba2c048cf906bedb8e3ed.bindTooltip(
#                 `&lt;div&gt;
#                      Simpang Lima
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_0d00717e7e0efa9d1fd3f5c027566460 = L.marker(
#                 [-6.9892, 110.4452],
#                 {
# }
#             ).addTo(map_657428fcbb78bf5e0f3af1cea024efef);
#
#
#         var popup_a47f7cd31739713bbb62bd2914644dc2 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_603c8adab574ae53f6a1d549e65d8cdd = $(`&lt;div id=&quot;html_603c8adab574ae53f6a1d549e65d8cdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;&lt;b&gt;Masjid Agung Jawa Tengah&lt;/b&gt;&lt;/h4&gt;&lt;i&gt;Tempat Ibadah (Umum)&lt;/i&gt;&lt;br&gt;&lt;br&gt;Masjid besar dengan arsitektur megah dan menara pandang Asmaul Husna.&lt;br&gt;&lt;br&gt;Koordinat: (-6.9892, 110.4452)&lt;/div&gt;`)[0];
#                 popup_a47f7cd31739713bbb62bd2914644dc2.setContent(html_603c8adab574ae53f6a1d549e65d8cdd);
#
#
#
#         marker_0d00717e7e0efa9d1fd3f5c027566460.bindPopup(popup_a47f7cd31739713bbb62bd2914644dc2)
#         ;
#
#
#
#
#             marker_0d00717e7e0efa9d1fd3f5c027566460.bindTooltip(
#                 `&lt;div&gt;
#                      Masjid Agung Jawa Tengah
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_fcf86ec6d3b5cdd87fda77586b8f4749 = L.marker(
#                 [-6.998, 110.403],
#                 {
# }
#             ).addTo(map_657428fcbb78bf5e0f3af1cea024efef);

# %% [markdown]
# #Penugasan

# %% [markdown]
# ##Tambah Data & Kelas

# %%
# Membuat/menimpa file konfigurasi peta
with open("config_peta.txt", "w") as f:
    f.write("-6.9929\n")
    f.write("110.4200\n")
    f.write("13\n")
print("File config_peta.txt berhasil dibuat.")

# Membuat/menimpa file CSV dengan tambahan 3 data baru
csv_data = """Nama,Latitude,Longitude,Tipe,Deskripsi
Lawang Sewu,-6.9840,110.4105,Wisata Sejarah,Bangunan bersejarah peninggalan Belanda dengan banyak pintu.
Simpang Lima,-6.9929,110.4200,Landmark,"Alun-alun pusat kota Semarang, tempat berkumpul populer."
Masjid Agung Jawa Tengah,-6.9892,110.4452,Tempat Ibadah,Masjid besar dengan arsitektur megah dan menara pandang Asmaul Husna.
Klenteng Sam Poo Kong,-6.9980,110.4030,Tempat Ibadah,Klenteng bersejarah peninggalan Laksamana Cheng Ho.
Brown Canyon,-7.0375,110.4875,Wisata Alam,"Tebing bekas penambangan galian C yang unik menyerupai Grand Canyon."
Lumpia Gang Lombok,-6.9718,110.4255,Kuliner,Salah satu tempat makan lumpia legendaris dan otentik di Semarang.
Kota Lama,-6.9690,110.4250,Wisata Sejarah,"Kawasan cagar budaya dengan bangunan-bangunan kuno bergaya Eropa."
Pantai Marina,-6.9585,110.3875,Wisata Alam,Kawasan pantai rekreasi di bagian utara kota.
Kampoeng Kopi Banaran,-7.2780,110.4010,Wisata Alam,"Agrowisata kebun kopi dengan pemandangan dan restoran."
Toko Oen,-6.9715,110.4235,Kuliner,Restoran dan toko es krim legendaris sejak zaman kolonial.
Kantor Gubernur Jateng,-6.9936,110.4206,Kantor Pemerintahan,Pusat pemerintahan Provinsi Jawa Tengah.
Museum Ronggowarsito,-6.9830,110.3888,Museum,Museum sejarah dan budaya Jawa Tengah.
Taman Srigunting,-6.9682,110.4272,Taman Kota,Taman ikonik di tengah Kota Lama Semarang.
"""

with open("lokasi_semarang.csv", "w", encoding="utf-8") as f:
    f.write(csv_data)
print("File lokasi_semarang.csv berhasil diperbarui dengan data baru.")

import pandas as pd
from abc import ABC, abstractmethod

# 1. Kelas Dasar & Praktikum Sebelumnya
class Lokasi(ABC):
    def __init__(self, nama: str, latitude: float, longitude: float):
        self.nama = str(nama) if nama else "Tanpa Nama"
        try:
            self.latitude, self.longitude = float(latitude), float(longitude)
        except (ValueError, TypeError):
            self.latitude, self.longitude = 0.0, 0.0

    def get_koordinat(self) -> tuple: return (self.latitude, self.longitude)

    @abstractmethod
    def get_info_popup(self) -> str: pass

class TempatWisata(Lokasi):
    def __init__(self, nama, lat, lon, jenis, deskripsi):
        super().__init__(nama, lat, lon)
        self.jenis_wisata, self.deskripsi = str(jenis), str(deskripsi)
    def get_info_popup(self): return f"<h4><b>{self.nama}</b></h4><i>{self.jenis_wisata}</i><br><br>{self.deskripsi}<br>Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})"

class Kuliner(Lokasi):
    def __init__(self, nama, lat, lon, menu_andalan):
        super().__init__(nama, lat, lon)
        self.menu_andalan = str(menu_andalan)
    def get_info_popup(self): return f"<h4><b>{self.nama}</b></h4><i>Kuliner</i><br><br>Menu: {self.menu_andalan}<br>Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})"

class TempatIbadah(Lokasi):
    def __init__(self, nama, lat, lon, agama, deskripsi):
        super().__init__(nama, lat, lon)
        self.agama, self.deskripsi = str(agama), str(deskripsi)
    def get_info_popup(self): return f"<h4><b>{self.nama}</b></h4><i>Tempat Ibadah ({self.agama})</i><br><br>{self.deskripsi}<br>Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})"


# Kelas Baru
class KantorPemerintahan(Lokasi):
    def __init__(self, nama, lat, lon, deskripsi):
        super().__init__(nama, lat, lon)
        self.deskripsi = str(deskripsi)
    def get_info_popup(self):
        return f"<h4><b>{self.nama}</b></h4><i>Kantor Pemerintahan</i><br><br>{self.deskripsi}<br>Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})"

class FasilitasPublik(Lokasi): # Untuk Museum & Taman
    def __init__(self, nama, lat, lon, tipe, deskripsi):
        super().__init__(nama, lat, lon)
        self.tipe, self.deskripsi = str(tipe), str(deskripsi)
    def get_info_popup(self):
        return f"<h4><b>{self.nama}</b></h4><i>{self.tipe}</i><br><br>{self.deskripsi}<br>Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})"


#Modifikasi buat_objek
def buat_objek_lokasi_dari_df(dataframe: pd.DataFrame) -> list:
    list_objek = []
    if dataframe is None or dataframe.empty: return list_objek

    for _, row in dataframe.iterrows():
        nama, lat, lon = row.get('Nama'), row.get('Latitude'), row.get('Longitude')
        tipe, deskripsi = row.get('Tipe', 'Lainnya'), row.get('Deskripsi', '')

        if pd.isna(nama) or pd.isna(lat) or pd.isna(lon): continue

        try:
            if 'Wisata' in tipe or tipe == 'Landmark':
                objek = TempatWisata(nama, lat, lon, tipe, deskripsi)
            elif tipe == 'Kuliner':
                objek = Kuliner(nama, lat, lon, deskripsi)
            elif 'Ibadah' in tipe:
                agama_info = "Islam" if "Islam" in tipe else "Tridharma" if "Klenteng" in tipe else "Umum"
                objek = TempatIbadah(nama, lat, lon, agama_info, deskripsi)

            #Logika Untuk Tipe Baru
            elif tipe == 'Kantor Pemerintahan':
                objek = KantorPemerintahan(nama, lat, lon, deskripsi)
            elif tipe in ['Museum', 'Taman Kota']:
                objek = FasilitasPublik(nama, lat, lon, tipe, deskripsi)
            else:
                continue

            list_objek.append(objek)
        except Exception as e:
            print(f"Error membuat objek {nama}: {e}")

    return list_objek
# Out:
# File config_peta.txt berhasil dibuat.
# File lokasi_semarang.csv berhasil diperbarui dengan data baru.

# %% [markdown]
# ##Kustomisasi Marker Folium

# %%
import folium

def buat_peta_lokasi_poin_b(list_objek: list, file_output: str):
    # Untuk sementara, titik tengah peta di-hardcode (karena Poin C belum diaplikasikan)
    peta = folium.Map(location=[-6.9929, 110.4200], zoom_start=13, tiles="OpenStreetMap")

    for lok in list_objek:
        koordinat = lok.get_koordinat()
        if koordinat != (0.0, 0.0):

            # isinstance dan Warna
            warna_marker, ikon = 'blue', 'info-sign' # Default

            if isinstance(lok, TempatWisata):
                warna_marker, ikon = 'green', 'camera'
            elif isinstance(lok, Kuliner):
                warna_marker, ikon = 'red', 'cutlery'
            elif isinstance(lok, TempatIbadah):
                warna_marker, ikon = 'purple', 'bookmark'
            elif isinstance(lok, KantorPemerintahan):
                warna_marker, ikon = 'gray', 'briefcase'
            elif isinstance(lok, FasilitasPublik):
                warna_marker, ikon = 'orange', 'tree-conifer'

            folium.Marker(
                location=koordinat,
                popup=folium.Popup(lok.get_info_popup(), max_width=300),
                tooltip=lok.nama,
                icon=folium.Icon(color=warna_marker, icon=ikon)
            ).add_to(peta)

    peta.save(file_output)
    return peta

# %% [markdown]
# ##Baca Konfigurasi Peta dari File

# %%
# %%writefile config_peta.txt
# -6.9929
# 110.4200
# 13
# Out:
# Overwriting config_peta.txt

# %%
FILE_CONFIG = "config_peta.txt"

def buat_peta_lokasi_final(list_objek: list, file_output: str):

    # (Baca Config txt)
    lat_tengah, lon_tengah, zoom_awal = -6.9929, 110.4200, 13 # Nilai default jika error

    try:
        with open(FILE_CONFIG, 'r') as f:
            lines = f.readlines()
            lat_tengah = float(lines[0].strip())
            lon_tengah = float(lines[1].strip())
            zoom_awal = int(lines[2].strip())
        print(f"Berhasil membaca file konfigurasi: Lat={lat_tengah}, Lon={lon_tengah}, Zoom={zoom_awal}")
    except (FileNotFoundError, ValueError, IndexError) as e:
        print(f"Gagal membaca konfigurasi ({e}), beralih menggunakan nilai default.")

    # Terapkan nilai config ke Folium Map
    peta = folium.Map(location=[lat_tengah, lon_tengah], zoom_start=zoom_awal, tiles="OpenStreetMap")

    # Isinstance Marker
    for lok in list_objek:
        koordinat = lok.get_koordinat()
        if koordinat != (0.0, 0.0):
            warna_marker, ikon = 'blue', 'info-sign'

            if isinstance(lok, TempatWisata): warna_marker, ikon = 'green', 'camera'
            elif isinstance(lok, Kuliner): warna_marker, ikon = 'red', 'cutlery'
            elif isinstance(lok, TempatIbadah): warna_marker, ikon = 'purple', 'bookmark'
            elif isinstance(lok, KantorPemerintahan): warna_marker, ikon = 'gray', 'briefcase'
            elif isinstance(lok, FasilitasPublik): warna_marker, ikon = 'orange', 'tree-conifer'

            folium.Marker(
                location=koordinat,
                popup=folium.Popup(lok.get_info_popup(), max_width=300),
                tooltip=lok.nama,
                icon=folium.Icon(color=warna_marker, icon=ikon)
            ).add_to(peta)

    peta.save(file_output)
    return peta

# %% [markdown]
# ##Kode Utama

# %%
NAMA_FILE_CSV = "lokasi_semarang.csv"
NAMA_FILE_PETA = "peta_hasil_penugasan.html"

print("=== MEMULAI PROGRAM UTAMA SIG ===")

# Membaca data CSV dengan Pandas
df_tugas = pd.read_csv(NAMA_FILE_CSV)

# Konversi DataFrame menjadi Objek OOP
list_semua_lokasi = buat_objek_lokasi_dari_df(df_tugas)
print(f"Total {len(list_semua_lokasi)} objek berhasil diinstansiasi.")

# Membuat Peta Kustom dengan Config
peta_akhir = buat_peta_lokasi_final(list_semua_lokasi, NAMA_FILE_PETA)
print("=== PROGRAM SELESAI ===")

# Tampilkan visualisasi peta di Colab
peta_akhir
# Out:
# === MEMULAI PROGRAM UTAMA SIG ===
# Total 13 objek berhasil diinstansiasi.
# Berhasil membaca file konfigurasi: Lat=-6.9929, Lon=110.42, Zoom=13
# === PROGRAM SELESAI ===
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b909a561d8cc1edbf8947cf3241cdbe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b909a561d8cc1edbf8947cf3241cdbe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b909a561d8cc1edbf8947cf3241cdbe = L.map(
#                 &quot;map_9b909a561d8cc1edbf8947cf3241cdbe&quot;,
#                 {
#                     center: [-6.9929, 110.42],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_98006182cfd2d7474d4ed90c2e671f74 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_98006182cfd2d7474d4ed90c2e671f74.addTo(map_9b909a561d8cc1edbf8947cf3241cdbe);
#
#
#             var marker_dae96093407bf6ff13ec8f7ae56efb72 = L.marker(
#                 [-6.984, 110.4105],
#                 {
# }
#             ).addTo(map_9b909a561d8cc1edbf8947cf3241cdbe);
#
#
#             var icon_beb5b82627b26587e030acd9f24e71e4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;camera&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4a0c7c1bc5199756e5a7a6096663dd66 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_f6177cf15276ee6c9c5ac7bceab3400f = $(`&lt;div id=&quot;html_f6177cf15276ee6c9c5ac7bceab3400f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;&lt;b&gt;Lawang Sewu&lt;/b&gt;&lt;/h4&gt;&lt;i&gt;Wisata Sejarah&lt;/i&gt;&lt;br&gt;&lt;br&gt;Bangunan bersejarah peninggalan Belanda dengan banyak pintu.&lt;br&gt;Koordinat: (-6.9840, 110.4105)&lt;/div&gt;`)[0];
#                 popup_4a0c7c1bc5199756e5a7a6096663dd66.setContent(html_f6177cf15276ee6c9c5ac7bceab3400f);
#
#
#
#         marker_dae96093407bf6ff13ec8f7ae56efb72.bindPopup(popup_4a0c7c1bc5199756e5a7a6096663dd66)
#         ;
#
#
#
#
#             marker_dae96093407bf6ff13ec8f7ae56efb72.bindTooltip(
#                 `&lt;div&gt;
#                      Lawang Sewu
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_dae96093407bf6ff13ec8f7ae56efb72.setIcon(icon_beb5b82627b26587e030acd9f24e71e4);
#
#
#             var marker_87e1ec5dea2a57faa323730210c1cdb3 = L.marker(
#                 [-6.9929, 110.42],
#                 {
# }
#             ).addTo(map_9b909a561d8cc1edbf8947cf3241cdbe);
#
#
#             var icon_1dfc7bf0d44cc4f04d68a744a912f9ee = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;camera&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9c417081197faca16e35fa8da7964e11 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_eee1fa23e13ea537829a749d27a981ba = $(`&lt;div id=&quot;html_eee1fa23e13ea537829a749d27a981ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;&lt;b&gt;Simpang Lima&lt;/b&gt;&lt;/h4&gt;&lt;i&gt;Landmark&lt;/i&gt;&lt;br&gt;&lt;br&gt;Alun-alun pusat kota Semarang, tempat berkumpul populer.&lt;br&gt;Koordinat: (-6.9929, 110.4200)&lt;/div&gt;`)[0];
#                 popup_9c417081197faca16e35fa8da7964e11.setContent(html_eee1fa23e13ea537829a749d27a981ba);
#
#
#
#         marker_87e1ec5dea2a57faa323730210c1cdb3.bindPopup(popup_9c417081197faca16e35fa8da7964e11)
#         ;
#
#
#
#
#             marker_87e1ec5dea2a57faa323730210c1cdb3.bindTooltip(
#                 `&lt;div&gt;
#                      Simpang Lima
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_87e1ec5dea2a57faa323730210c1cdb3.setIcon(icon_1dfc7bf0d44cc4f04d68a744a912f9ee);
#
#
#             var marker_d94e5bd4f6c87fbcce798abce291b506 = L.marker(
#                 [-6.9892, 110.4452],
#                 {
# }
#             ).addTo(map_9b909a561d8cc1edbf8947cf3241cdbe);
#
#
#             var icon_44427effac6bc078709b07993dad1874 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;bookmark&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&q
